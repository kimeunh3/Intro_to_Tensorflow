# %% [markdown]
# <a href="https://colab.research.google.com/github/kimeunh3/Intro_to_Tensorflow/blob/main/%EC%8B%A4%EC%8A%B57_%ED%95%99%EC%8A%B5%EC%9D%B4_%EC%9E%98%EB%90%98%EB%8A%94_%EB%AA%A8%EB%8D%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 학습이 잘 되는 모델
#  - 사용할 레이어
#     - `tf.keras.layers.BatchNormalization()`
#     - `tf.keras.layers.Activation('swish')`
#  - 데이터
#     - 보스턴 집값 예측: ['https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv'](https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv)
#     - 아이리스 품종 분류: ['https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/iris.csv'](https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/iris.csv)

# %% [markdown]
# # 보스턴 집값 예측

# %%
# 라이브러리 사용
import tensorflow as tf
import pandas as pd

# %%
# 1. 과거의 데이터를 준비합니다.
파일경로 = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv'
보스턴 = pd.read_csv(파일경로)
print(보스턴.columns)
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
# 독립변수, 종속변수
독립 = 보스턴[['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age',
       'dis', 'rad', 'tax', 'ptratio', 'b', 'lstat']]
종속 = 보스턴[['medv']]
print(독립.shape, 종속.shape)
# Out:
# (506, 13) (506, 1)

# %%
# 2. 모델의 구조를 만듭니다.
X = tf.keras.layers.Input(shape=[13])
H = tf.keras.layers.Dense(8, activation='swish')(X)
H = tf.keras.layers.Dense(8, activation='swish')(H)
H = tf.keras.layers.Dense(8, activation='swish')(H)
Y = tf.keras.layers.Dense(1)(H)
model = tf.keras.models.Model(X, Y)
model.compile(loss='mse')

# %%
# 3. 데이터로 모델을 학습(FIT)합니다.
model.fit(독립, 종속, epochs=100, verbose=0)
model.fit(독립, 종속, epochs=10)
# Out:
# Epoch 1/10
# 16/16 [==============================] - 0s 2ms/step - loss: 49.8503
# Epoch 2/10
# 16/16 [==============================] - 0s 2ms/step - loss: 49.9613
# Epoch 3/10
# 16/16 [==============================] - 0s 2ms/step - loss: 50.1859
# Epoch 4/10
# 16/16 [==============================] - 0s 2ms/step - loss: 49.2361
# Epoch 5/10
# 16/16 [==============================] - 0s 2ms/step - loss: 49.4504
# Epoch 6/10
# 16/16 [==============================] - 0s 2ms/step - loss: 49.7906
# Epoch 7/10
# 16/16 [==============================] - 0s 2ms/step - loss: 49.1829
# Epoch 8/10
# 16/16 [==============================] - 0s 2ms/step - loss: 48.9902
# Epoch 9/10
# 16/16 [==============================] - 0s 2ms/step - loss: 49.3438
# Epoch 10/10
# 16/16 [==============================] - 0s 2ms/step - loss: 49.1907

# %%
# 2. 모델의 구조를 만듭니다.
X = tf.keras.layers.Input(shape=[13])

H = tf.keras.layers.Dense(8)(X)
H = tf.keras.layers.BatchNormalization()(H)
H = tf.keras.layers.Activation('swish')(H)

H = tf.keras.layers.Dense(8)(H)
H = tf.keras.layers.BatchNormalization()(H)
H = tf.keras.layers.Activation('swish')(H)

H = tf.keras.layers.Dense(8)(H)
H = tf.keras.layers.BatchNormalization()(H)
H = tf.keras.layers.Activation('swish')(H)

Y = tf.keras.layers.Dense(1)(H)
model = tf.keras.models.Model(X, Y)
model.compile(loss='mse')

# %%
# 3. 데이터로 모델을 학습(FIT)합니다.
model.fit(독립, 종속, epochs=100, verbose=0)
model.fit(독립, 종속, epochs=10)
# Out:
# Epoch 1/10
# 16/16 [==============================] - 0s 2ms/step - loss: 26.2398
# Epoch 2/10
# 16/16 [==============================] - 0s 2ms/step - loss: 25.8481
# Epoch 3/10
# 16/16 [==============================] - 0s 2ms/step - loss: 21.1181
# Epoch 4/10
# 16/16 [==============================] - 0s 2ms/step - loss: 25.9029
# Epoch 5/10
# 16/16 [==============================] - 0s 2ms/step - loss: 27.8503
# Epoch 6/10
# 16/16 [==============================] - 0s 2ms/step - loss: 22.7421
# Epoch 7/10
# 16/16 [==============================] - 0s 2ms/step - loss: 22.5998
# Epoch 8/10
# 16/16 [==============================] - 0s 3ms/step - loss: 22.0161
# Epoch 9/10
# 16/16 [==============================] - 0s 2ms/step - loss: 25.4129
# Epoch 10/10
# 16/16 [==============================] - 0s 2ms/step - loss: 20.3192

# %% [markdown]
# # 아이리스 품종 분류

# %%
# 과거의 데이터를 준비합니다.
파일경로 = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/iris.csv'
아이리스 = pd.read_csv(파일경로)

# 원인핫코딩
아이리스 = pd.get_dummies(아이리스)

print(아이리스.columns)
# Out:
# Index(['꽃잎길이', '꽃잎폭', '꽃받침길이', '꽃받침폭', '품종_setosa', '품종_versicolor',
#        '품종_virginica'],
#       dtype='object')

# %%
# 독립변수, 종속변수
독립 = 아이리스[['꽃잎길이', '꽃잎폭', '꽃받침길이', '꽃받침폭']]
종속 = 아이리스[['품종_setosa', '품종_versicolor', '품종_virginica']]
print(독립.shape, 종속.shape)
# Out:
# (150, 4) (150, 3)

# %%
# 2. 모델의 구조를 만듭니다.
X = tf.keras.layers.Input(shape=[4])
H = tf.keras.layers.Dense(8, activation='swish')(X)
H = tf.keras.layers.Dense(8, activation='swish')(H)
H = tf.keras.layers.Dense(8, activation='swish')(H)
Y = tf.keras.layers.Dense(3, activation='softmax')(H)
model = tf.keras.models.Model(X, Y)
model.compile(loss='categorical_crossentropy',
              metrics='accuracy')

# %%
# 3. 데이터로 모델을 학습(FIT)합니다.
model.fit(독립, 종속, epochs=1000, batch_size=150)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 1s 731ms/step - loss: 1.4134 - accuracy: 0.3333
# Epoch 2/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.3320 - accuracy: 0.3533
# Epoch 3/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2893 - accuracy: 0.3867
# Epoch 4/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2561 - accuracy: 0.4133
# Epoch 5/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2280 - accuracy: 0.4200
# Epoch 6/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2035 - accuracy: 0.4200
# Epoch 7/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1815 - accuracy: 0.4200
# Epoch 8/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1614 - accuracy: 0.4400
# Epoch 9/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1429 - accuracy: 0.4467
# Epoch 10/1000
# ...

# %%
# 2. 모델의 구조를 만듭니다.
X = tf.keras.layers.Input(shape=[4])

H = tf.keras.layers.Dense(8)(X)
H = tf.keras.layers.BatchNormalization()(H)
H = tf.keras.layers.Activation('swish')(H)

H = tf.keras.layers.Dense(8)(H)
H = tf.keras.layers.BatchNormalization()(H)
H = tf.keras.layers.Activation('swish')(H)

H = tf.keras.layers.Dense(8)(H)
H = tf.keras.layers.BatchNormalization()(H)
H = tf.keras.layers.Activation('swish')(H)

Y = tf.keras.layers.Dense(3, activation='softmax')(H)
model = tf.keras.models.Model(X, Y)
model.compile(loss='categorical_crossentropy',
              metrics='accuracy')

# %%
# 3. 데이터로 모델을 학습(FIT)합니다.
model.fit(독립, 종속, epochs=1000, batch_size=150)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 2s 2s/step - loss: 1.3425 - accuracy: 0.1733
# Epoch 2/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2868 - accuracy: 0.2200
# Epoch 3/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2469 - accuracy: 0.2467
# Epoch 4/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2135 - accuracy: 0.2667
# Epoch 5/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1840 - accuracy: 0.2733
# Epoch 6/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1570 - accuracy: 0.2933
# Epoch 7/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1317 - accuracy: 0.3200
# Epoch 8/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1077 - accuracy: 0.3267
# Epoch 9/1000
# 1/1 [==============================] - 0s 16ms/step - loss: 1.0847 - accuracy: 0.3600
# Epoch 10/1000
# ...
